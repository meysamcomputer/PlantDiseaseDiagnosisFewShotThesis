# %% [markdown]
# # Code for running SiameseNet and TripletNet on BRACOL Dataset
#
# ***The code used in this notebook is mostly from [this](https://github.com/adambielski/siamese-triplet/). If you are interested in it, check it out, it is extremely well documented***

# %% [markdown]
# ***Install libs***

# %%
import sys
sys.path.insert(0,'f:/Meysam-Khodarahi/PlantDiseaseDiagnosisFewShotLearning/siamese_triplet_net/src/')
import torch
from transformers import ViTForImageClassification, ViTFeatureExtractor
from dataloaders import get_train_transforms, get_val_transforms, get_triplet_dataloader
from networks import TripletNet 
from models import MobileNetv2
from models import EfficientNetB4
from losses import TripletLoss
from trainer import fit
import torchvision
import timm
from IPython.display import clear_output 
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.manifold import TSNE
from torch import nn
from torch.optim.lr_scheduler import CosineAnnealingLR
from sklearn.metrics import accuracy_score, f1_score , precision_score , recall_score

# استفاده از مدل EfficientNet به جای MobileNetv2 برای استخراج ویژگی‌ها
embedding_net =EfficientNetB4() #timm.create_model('efficientnet_b0', pretrained=True)  # استفاده از مدل EfficientNet
siamese_model = TripletNet(embedding_net=embedding_net)

optimizer = torch.optim.Adam(siamese_model.parameters(), lr=1e-4)  # تغییر به Adam برای بهبود عملکرد
lr_scheduler = CosineAnnealingLR(optimizer, T_max=10, eta_min=1e-6)  # استفاده از Cosine Annealing برای تغییر نرخ یادگیری
loss_fn = TripletLoss(1.)
n_epochs = 100  # تعداد epochs
device = torch.cuda.is_available()

if device:
    siamese_model.cuda()
# Out:
# Loaded pretrained weights for efficientnet-b4

# %% [markdown]
# ***Import some libs***

# %%
# بارگذاری داده‌ها
path_data = 'f:/Meysam-Khodarahi/PlantDiseaseDiagnosisFewShotLearning/siamese_triplet_net/src/dataset'
triplet_train_loader = get_triplet_dataloader(root=path_data + '/train/', batch_size=5, transforms=get_train_transforms())
triplet_val_loader = get_triplet_dataloader(root=path_data + '/val/', batch_size=5, transforms=get_val_transforms())

# %% [markdown]
# ***Define model hiperparams***

# %%
# آموزش مدل Siamese
fit(triplet_train_loader, triplet_val_loader, siamese_model, loss_fn, optimizer, lr_scheduler, n_epochs, device, log_interval=10)
# Out:
# Train: [0/225 (0%)]	Loss: 1.011379
# Train: [50/225 (22%)]	Loss: 0.833505
# Train: [100/225 (44%)]	Loss: 0.786644
# Train: [150/225 (67%)]	Loss: 0.737439
# Train: [200/225 (89%)]	Loss: 0.674816
# Epoch: 1/100. Train set: Average loss: 0.7615
# Epoch: 1/100. Validation set: Average loss: 0.7490
# Estimated time of epoch: 57.73 s
# ETA:96.22 min
# Train: [0/225 (0%)]	Loss: 0.401873
# Train: [50/225 (22%)]	Loss: 0.672567
# Train: [100/225 (44%)]	Loss: 0.638669
# Train: [150/225 (67%)]	Loss: 0.617081
# Train: [200/225 (89%)]	Loss: 0.612824
# Epoch: 2/100. Train set: Average loss: 0.6134
# Epoch: 2/100. Validation set: Average loss: 0.6488
# Estimated time of epoch: 57.6 s
# ETA:95.04 min
# Train: [0/225 (0%)]	Loss: 0.601027
# Train: [50/225 (22%)]	Loss: 0.535058
# Train: [100/225 (44%)]	Loss: 0.476019
# Train: [150/225 (67%)]	Loss: 0.456083
# Train: [200/225 (89%)]	Loss: 0.349653
# Epoch: 3/100. Train set: Average loss: 0.4566
# Epoch: 3/100. Validation set: Average loss: 0.5497
# Estimated time of epoch: 58.91 s
# ETA:96.22 min
# Train: [0/225 (0%)]	Loss: 0.218418
# Train: [50/225 (22%)]	Loss: 0.372473
# Train: [100/225 (44%)]	Loss: 0.248940
# Train: [150/225 (67%)]	Loss: 0.425613
# Train: [200/225 (89%)]	Loss: 0.391534
# Epoch: 4/100. Train set: Average loss: 0.3614
# Epoch: 4/100. Validation set: Average loss: 0.4854
# Estimated time of epoch: 59.49 s
# ETA:96.18 min
# Train: [0/225 (0%)]	Loss: 0.132496
# Train: [50/225 (22%)]	Loss: 0.396104
# Train: [100/225 (44%)]	Loss: 0.281669
# Train: [150/225 (67%)]	Loss: 0.301930
# Train: [200/225 (89%)]	Loss: 0.379171
# Epoch: 5/100. Train set: Average loss: 0.3249
# Epoch: 5/100. Validation set: Average loss: 0.4513
# Estimated time of epoch: 56.71 s
# ETA:90.74 min
# Train: [0/225 (0%)]	Loss: 0.329569
# Train: [50/225 (22%)]	Loss: 0.364196
# Train: [100/225 (44%)]	Loss: 0.313065
# Train: [150/225 (67%)]	Loss: 0.243879
# Train: [200/225 (89%)]	Loss: 0.330014
# Epoch: 6/100. Train set: Average loss: 0.3089
# Epoch: 6/100. Validation set: Average loss: 0.4176
# Estimated time of epoch: 56.79 s
# ETA:89.92 min
# Train: [0/225 (0%)]	Loss: 0.192420
# Train: [50/225 (22%)]	Loss: 0.231396
# Train: [100/225 (44%)]	Loss: 0.352681
# Train: [150/225 (67%)]	Loss: 0.181108
# Train: [200/225 (89%)]	Loss: 0.325932
# Epoch: 7/100. Train set: Average loss: 0.2743
# Epoch: 7/100. Validation set: Average loss: 0.4145
# Estimated time of epoch: 56.16 s
# ETA:87.98 min
# Train: [0/225 (0%)]	Loss: 0.450360
# Train: [50/225 (22%)]	Loss: 0.219866
# Train: [100/225 (44%)]	Loss: 0.350281
# Train: [150/225 (67%)]	Loss: 0.200354
# Train: [200/225 (89%)]	Loss: 0.273356
# Epoch: 8/100. Train set: Average loss: 0.2844
# Epoch: 8/100. Validation set: Average loss: 0.3945
# Estimated time of epoch: 55.88 s
# ETA:86.61 min
# Train: [0/225 (0%)]	Loss: 0.494314
# Train: [50/225 (22%)]	Loss: 0.283409
# Train: [100/225 (44%)]	Loss: 0.282263
# Train: [150/225 (67%)]	Loss: 0.197011
# Train: [200/225 (89%)]	Loss: 0.224141
# Epoch: 9/100. Train set: Average loss: 0.2418
# Epoch: 9/100. Validation set: Average loss: 0.3905
# Estimated time of epoch: 55.99 s
# ETA:85.85 min
# Train: [0/225 (0%)]	Loss: 0.325171
# Train: [50/225 (22%)]	Loss: 0.194371
# Train: [100/225 (44%)]	Loss: 0.253762
# Train: [150/225 (67%)]	Loss: 0.222309
# Train: [200/225 (89%)]	Loss: 0.237234
# Epoch: 10/100. Train set: Average loss: 0.2367
# Epoch: 10/100. Validation set: Average loss: 0.4130
# Estimated time of epoch: 56.24 s
# ETA:85.3 min
# Train: [0/225 (0%)]	Loss: 0.208773
# Train: [50/225 (22%)]	Loss: 0.349544
# Train: [100/225 (44%)]	Loss: 0.205479
# Train: [150/225 (67%)]	Loss: 0.154629
# Train: [200/225 (89%)]	Loss: 0.253758
# Epoch: 11/100. Train set: Average loss: 0.2458
# Epoch: 11/100. Validation set: Average loss: 0.3907
# Estimated time of epoch: 56.04 s
# ETA:84.06 min
# Train: [0/225 (0%)]	Loss: 0.378888
# Train: [50/225 (22%)]	Loss: 0.176385
# Train: [100/225 (44%)]	Loss: 0.269658
# Train: [150/225 (67%)]	Loss: 0.267660
# Train: [200/225 (89%)]	Loss: 0.269632
# Epoch: 12/100. Train set: Average loss: 0.2450
# Epoch: 12/100. Validation set: Average loss: 0.4021
# Estimated time of epoch: 56.22 s
# ETA:83.39 min
# Train: [0/225 (0%)]	Loss: 0.107096
# Train: [50/225 (22%)]	Loss: 0.176336
# Train: [100/225 (44%)]	Loss: 0.267758
# Train: [150/225 (67%)]	Loss: 0.251595
# Train: [200/225 (89%)]	Loss: 0.192456
# Epoch: 13/100. Train set: Average loss: 0.2121
# Epoch: 13/100. Validation set: Average loss: 0.3882
# Estimated time of epoch: 56.28 s
# ETA:82.54 min
# Train: [0/225 (0%)]	Loss: 0.296553
# Train: [50/225 (22%)]	Loss: 0.400724
# Train: [100/225 (44%)]	Loss: 0.299006
# Train: [150/225 (67%)]	Loss: 0.195746
# Train: [200/225 (89%)]	Loss: 0.248313
# Epoch: 14/100. Train set: Average loss: 0.2873
# Epoch: 14/100. Validation set: Average loss: 0.3802
# Estimated time of epoch: 56.35 s
# ETA:81.71 min
# Train: [0/225 (0%)]	Loss: 0.389346
# Train: [50/225 (22%)]	Loss: 0.296547
# Train: [100/225 (44%)]	Loss: 0.238936
# Train: [150/225 (67%)]	Loss: 0.127266
# Train: [200/225 (89%)]	Loss: 0.132198
# Epoch: 15/100. Train set: Average loss: 0.1990
# Epoch: 15/100. Validation set: Average loss: 0.3677
# Estimated time of epoch: 56.46 s
# ETA:80.93 min
# Train: [0/225 (0%)]	Loss: 0.228675
# Train: [50/225 (22%)]	Loss: 0.184860
# Train: [100/225 (44%)]	Loss: 0.213616
# Train: [150/225 (67%)]	Loss: 0.210229
# Train: [200/225 (89%)]	Loss: 0.190222
# Epoch: 16/100. Train set: Average loss: 0.2076
# Epoch: 16/100. Validation set: Average loss: 0.3564
# Estimated time of epoch: 55.81 s
# ETA:79.06 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.165841
# Train: [100/225 (44%)]	Loss: 0.115667
# Train: [150/225 (67%)]	Loss: 0.134266
# Train: [200/225 (89%)]	Loss: 0.178326
# Epoch: 17/100. Train set: Average loss: 0.1535
# Epoch: 17/100. Validation set: Average loss: 0.3371
# Estimated time of epoch: 56.52 s
# ETA:79.13 min
# Train: [0/225 (0%)]	Loss: 0.002069
# Train: [50/225 (22%)]	Loss: 0.153519
# Train: [100/225 (44%)]	Loss: 0.098661
# Train: [150/225 (67%)]	Loss: 0.237472
# Train: [200/225 (89%)]	Loss: 0.171019
# Epoch: 18/100. Train set: Average loss: 0.1573
# Epoch: 18/100. Validation set: Average loss: 0.3401
# Estimated time of epoch: 56.54 s
# ETA:78.21 min
# Train: [0/225 (0%)]	Loss: 0.039134
# Train: [50/225 (22%)]	Loss: 0.055663
# Train: [100/225 (44%)]	Loss: 0.066320
# Train: [150/225 (67%)]	Loss: 0.156116
# Train: [200/225 (89%)]	Loss: 0.259456
# Epoch: 19/100. Train set: Average loss: 0.1387
# Epoch: 19/100. Validation set: Average loss: 0.3152
# Estimated time of epoch: 56.02 s
# ETA:76.56 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.132253
# Train: [100/225 (44%)]	Loss: 0.223019
# Train: [150/225 (67%)]	Loss: 0.171996
# Train: [200/225 (89%)]	Loss: 0.097652
# Epoch: 20/100. Train set: Average loss: 0.1610
# Epoch: 20/100. Validation set: Average loss: 0.2845
# Estimated time of epoch: 56.15 s
# ETA:75.8 min
# Train: [0/225 (0%)]	Loss: 0.080363
# Train: [50/225 (22%)]	Loss: 0.136180
# Train: [100/225 (44%)]	Loss: 0.132574
# Train: [150/225 (67%)]	Loss: 0.156585
# Train: [200/225 (89%)]	Loss: 0.102279
# Epoch: 21/100. Train set: Average loss: 0.1276
# Epoch: 21/100. Validation set: Average loss: 0.3039
# Estimated time of epoch: 56.98 s
# ETA:75.97 min
# Train: [0/225 (0%)]	Loss: 0.236683
# Train: [50/225 (22%)]	Loss: 0.152962
# Train: [100/225 (44%)]	Loss: 0.100365
# Train: [150/225 (67%)]	Loss: 0.168930
# Train: [200/225 (89%)]	Loss: 0.145485
# Epoch: 22/100. Train set: Average loss: 0.1499
# Epoch: 22/100. Validation set: Average loss: 0.2501
# Estimated time of epoch: 56.22 s
# ETA:74.02 min
# Train: [0/225 (0%)]	Loss: 0.184137
# Train: [50/225 (22%)]	Loss: 0.170975
# Train: [100/225 (44%)]	Loss: 0.171657
# Train: [150/225 (67%)]	Loss: 0.103263
# Train: [200/225 (89%)]	Loss: 0.142679
# Epoch: 23/100. Train set: Average loss: 0.1473
# Epoch: 23/100. Validation set: Average loss: 0.2594
# Estimated time of epoch: 56.44 s
# ETA:73.37 min
# Train: [0/225 (0%)]	Loss: 0.093321
# Train: [50/225 (22%)]	Loss: 0.122041
# Train: [100/225 (44%)]	Loss: 0.123759
# Train: [150/225 (67%)]	Loss: 0.085089
# Train: [200/225 (89%)]	Loss: 0.150899
# Epoch: 24/100. Train set: Average loss: 0.1139
# Epoch: 24/100. Validation set: Average loss: 0.2628
# Estimated time of epoch: 56.03 s
# ETA:71.91 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.154370
# Train: [100/225 (44%)]	Loss: 0.061971
# Train: [150/225 (67%)]	Loss: 0.107614
# Train: [200/225 (89%)]	Loss: 0.110678
# Epoch: 25/100. Train set: Average loss: 0.1045
# Epoch: 25/100. Validation set: Average loss: 0.2613
# Estimated time of epoch: 56.1 s
# ETA:71.06 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.129759
# Train: [100/225 (44%)]	Loss: 0.088635
# Train: [150/225 (67%)]	Loss: 0.078816
# Train: [200/225 (89%)]	Loss: 0.087334
# Epoch: 26/100. Train set: Average loss: 0.0996
# Epoch: 26/100. Validation set: Average loss: 0.2610
# Estimated time of epoch: 56.87 s
# ETA:71.09 min
# Train: [0/225 (0%)]	Loss: 0.075179
# Train: [50/225 (22%)]	Loss: 0.139737
# Train: [100/225 (44%)]	Loss: 0.129975
# Train: [150/225 (67%)]	Loss: 0.065459
# Train: [200/225 (89%)]	Loss: 0.112171
# Epoch: 27/100. Train set: Average loss: 0.1143
# Epoch: 27/100. Validation set: Average loss: 0.2419
# Estimated time of epoch: 56.11 s
# ETA:69.2 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.158609
# Train: [100/225 (44%)]	Loss: 0.108124
# Train: [150/225 (67%)]	Loss: 0.104198
# Train: [200/225 (89%)]	Loss: 0.089200
# Epoch: 28/100. Train set: Average loss: 0.1124
# Epoch: 28/100. Validation set: Average loss: 0.2437
# Estimated time of epoch: 56.86 s
# ETA:69.18 min
# Train: [0/225 (0%)]	Loss: 0.128335
# Train: [50/225 (22%)]	Loss: 0.064147
# Train: [100/225 (44%)]	Loss: 0.056093
# Train: [150/225 (67%)]	Loss: 0.074005
# Train: [200/225 (89%)]	Loss: 0.043710
# Epoch: 29/100. Train set: Average loss: 0.0662
# Epoch: 29/100. Validation set: Average loss: 0.2544
# Estimated time of epoch: 56.27 s
# ETA:67.52 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.114008
# Train: [100/225 (44%)]	Loss: 0.081937
# Train: [150/225 (67%)]	Loss: 0.059584
# Train: [200/225 (89%)]	Loss: 0.084469
# Epoch: 30/100. Train set: Average loss: 0.0875
# Epoch: 30/100. Validation set: Average loss: 0.2394
# Estimated time of epoch: 56.16 s
# ETA:66.46 min
# Train: [0/225 (0%)]	Loss: 0.013779
# Train: [50/225 (22%)]	Loss: 0.081064
# Train: [100/225 (44%)]	Loss: 0.125713
# Train: [150/225 (67%)]	Loss: 0.045243
# Train: [200/225 (89%)]	Loss: 0.225202
# Epoch: 31/100. Train set: Average loss: 0.1092
# Epoch: 31/100. Validation set: Average loss: 0.2397
# Estimated time of epoch: 55.89 s
# ETA:65.2 min
# Train: [0/225 (0%)]	Loss: 0.024822
# Train: [50/225 (22%)]	Loss: 0.055822
# Train: [100/225 (44%)]	Loss: 0.152384
# Train: [150/225 (67%)]	Loss: 0.043472
# Train: [200/225 (89%)]	Loss: 0.110648
# Epoch: 32/100. Train set: Average loss: 0.0864
# Epoch: 32/100. Validation set: Average loss: 0.2354
# Estimated time of epoch: 55.79 s
# ETA:64.16 min
# Train: [0/225 (0%)]	Loss: 0.137374
# Train: [50/225 (22%)]	Loss: 0.096640
# Train: [100/225 (44%)]	Loss: 0.125694
# Train: [150/225 (67%)]	Loss: 0.165510
# Train: [200/225 (89%)]	Loss: 0.079813
# Epoch: 33/100. Train set: Average loss: 0.1255
# Epoch: 33/100. Validation set: Average loss: 0.2252
# Estimated time of epoch: 56.47 s
# ETA:64.0 min
# Train: [0/225 (0%)]	Loss: 0.063427
# Train: [50/225 (22%)]	Loss: 0.091686
# Train: [100/225 (44%)]	Loss: 0.046504
# Train: [150/225 (67%)]	Loss: 0.101289
# Train: [200/225 (89%)]	Loss: 0.138140
# Epoch: 34/100. Train set: Average loss: 0.0859
# Epoch: 34/100. Validation set: Average loss: 0.2348
# Estimated time of epoch: 55.9 s
# ETA:62.42 min
# Train: [0/225 (0%)]	Loss: 0.035542
# Train: [50/225 (22%)]	Loss: 0.045564
# Train: [100/225 (44%)]	Loss: 0.099293
# Train: [150/225 (67%)]	Loss: 0.085566
# Train: [200/225 (89%)]	Loss: 0.065831
# Epoch: 35/100. Train set: Average loss: 0.0705
# Epoch: 35/100. Validation set: Average loss: 0.2223
# Estimated time of epoch: 56.07 s
# ETA:61.68 min
# Train: [0/225 (0%)]	Loss: 0.077217
# Train: [50/225 (22%)]	Loss: 0.047289
# Train: [100/225 (44%)]	Loss: 0.079649
# Train: [150/225 (67%)]	Loss: 0.085562
# Train: [200/225 (89%)]	Loss: 0.095534
# Epoch: 36/100. Train set: Average loss: 0.0807
# Epoch: 36/100. Validation set: Average loss: 0.2250
# Estimated time of epoch: 56.27 s
# ETA:60.96 min
# Train: [0/225 (0%)]	Loss: 0.069918
# Train: [50/225 (22%)]	Loss: 0.065218
# Train: [100/225 (44%)]	Loss: 0.137846
# Train: [150/225 (67%)]	Loss: 0.155463
# Train: [200/225 (89%)]	Loss: 0.049379
# Epoch: 37/100. Train set: Average loss: 0.0948
# Epoch: 37/100. Validation set: Average loss: 0.2118
# Estimated time of epoch: 56.35 s
# ETA:60.11 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.128096
# Train: [100/225 (44%)]	Loss: 0.093363
# Train: [150/225 (67%)]	Loss: 0.083169
# Train: [200/225 (89%)]	Loss: 0.120745
# Epoch: 38/100. Train set: Average loss: 0.0982
# Epoch: 38/100. Validation set: Average loss: 0.2192
# Estimated time of epoch: 56.55 s
# ETA:59.38 min
# Train: [0/225 (0%)]	Loss: 0.117881
# Train: [50/225 (22%)]	Loss: 0.112964
# Train: [100/225 (44%)]	Loss: 0.214845
# Train: [150/225 (67%)]	Loss: 0.144113
# Train: [200/225 (89%)]	Loss: 0.103407
# Epoch: 39/100. Train set: Average loss: 0.1353
# Epoch: 39/100. Validation set: Average loss: 0.2243
# Estimated time of epoch: 56.25 s
# ETA:58.12 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.048802
# Train: [100/225 (44%)]	Loss: 0.030740
# Train: [150/225 (67%)]	Loss: 0.019599
# Train: [200/225 (89%)]	Loss: 0.103482
# Epoch: 40/100. Train set: Average loss: 0.0456
# Epoch: 40/100. Validation set: Average loss: 0.2066
# Estimated time of epoch: 56.28 s
# ETA:57.22 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.094489
# Train: [100/225 (44%)]	Loss: 0.049703
# Train: [150/225 (67%)]	Loss: 0.191834
# Train: [200/225 (89%)]	Loss: 0.040644
# Epoch: 41/100. Train set: Average loss: 0.0897
# Epoch: 41/100. Validation set: Average loss: 0.2195
# Estimated time of epoch: 56.0 s
# ETA:56.0 min
# Train: [0/225 (0%)]	Loss: 0.158547
# Train: [50/225 (22%)]	Loss: 0.091426
# Train: [100/225 (44%)]	Loss: 0.063900
# Train: [150/225 (67%)]	Loss: 0.085213
# Train: [200/225 (89%)]	Loss: 0.093579
# Epoch: 42/100. Train set: Average loss: 0.0879
# Epoch: 42/100. Validation set: Average loss: 0.2129
# Estimated time of epoch: 55.98 s
# ETA:55.05 min
# Train: [0/225 (0%)]	Loss: 0.349706
# Train: [50/225 (22%)]	Loss: 0.145706
# Train: [100/225 (44%)]	Loss: 0.125521
# Train: [150/225 (67%)]	Loss: 0.061462
# Train: [200/225 (89%)]	Loss: 0.116662
# Epoch: 43/100. Train set: Average loss: 0.1133
# Epoch: 43/100. Validation set: Average loss: 0.2174
# Estimated time of epoch: 56.36 s
# ETA:54.48 min
# Train: [0/225 (0%)]	Loss: 0.036235
# Train: [50/225 (22%)]	Loss: 0.076931
# Train: [100/225 (44%)]	Loss: 0.149362
# Train: [150/225 (67%)]	Loss: 0.090945
# Train: [200/225 (89%)]	Loss: 0.040605
# Epoch: 44/100. Train set: Average loss: 0.0804
# Epoch: 44/100. Validation set: Average loss: 0.2079
# Estimated time of epoch: 56.38 s
# ETA:53.56 min
# Train: [0/225 (0%)]	Loss: 0.075537
# Train: [50/225 (22%)]	Loss: 0.073306
# Train: [100/225 (44%)]	Loss: 0.050983
# Train: [150/225 (67%)]	Loss: 0.073811
# Train: [200/225 (89%)]	Loss: 0.090849
# Epoch: 45/100. Train set: Average loss: 0.0772
# Epoch: 45/100. Validation set: Average loss: 0.1677
# Estimated time of epoch: 55.92 s
# ETA:52.19 min
# Train: [0/225 (0%)]	Loss: 0.036957
# Train: [50/225 (22%)]	Loss: 0.033270
# Train: [100/225 (44%)]	Loss: 0.087199
# Train: [150/225 (67%)]	Loss: 0.093110
# Train: [200/225 (89%)]	Loss: 0.071463
# Epoch: 46/100. Train set: Average loss: 0.0650
# Epoch: 46/100. Validation set: Average loss: 0.1703
# Estimated time of epoch: 56.17 s
# ETA:51.49 min
# Train: [0/225 (0%)]	Loss: 0.040862
# Train: [50/225 (22%)]	Loss: 0.106272
# Train: [100/225 (44%)]	Loss: 0.090151
# Train: [150/225 (67%)]	Loss: 0.098353
# Train: [200/225 (89%)]	Loss: 0.060086
# Epoch: 47/100. Train set: Average loss: 0.0831
# Epoch: 47/100. Validation set: Average loss: 0.1831
# Estimated time of epoch: 56.22 s
# ETA:50.6 min
# Train: [0/225 (0%)]	Loss: 0.027669
# Train: [50/225 (22%)]	Loss: 0.079837
# Train: [100/225 (44%)]	Loss: 0.086105
# Train: [150/225 (67%)]	Loss: 0.022581
# Train: [200/225 (89%)]	Loss: 0.071055
# Epoch: 48/100. Train set: Average loss: 0.0618
# Epoch: 48/100. Validation set: Average loss: 0.1781
# Estimated time of epoch: 59.47 s
# ETA:52.53 min
# Train: [0/225 (0%)]	Loss: 0.178225
# Train: [50/225 (22%)]	Loss: 0.060472
# Train: [100/225 (44%)]	Loss: 0.118736
# Train: [150/225 (67%)]	Loss: 0.071477
# Train: [200/225 (89%)]	Loss: 0.113536
# Epoch: 49/100. Train set: Average loss: 0.0872
# Epoch: 49/100. Validation set: Average loss: 0.1859
# Estimated time of epoch: 57.09 s
# ETA:49.48 min
# Train: [0/225 (0%)]	Loss: 0.005181
# Train: [50/225 (22%)]	Loss: 0.045201
# Train: [100/225 (44%)]	Loss: 0.060198
# Train: [150/225 (67%)]	Loss: 0.096603
# Train: [200/225 (89%)]	Loss: 0.038310
# Epoch: 50/100. Train set: Average loss: 0.0634
# Epoch: 50/100. Validation set: Average loss: 0.1747
# Estimated time of epoch: 56.03 s
# ETA:47.63 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.069600
# Train: [100/225 (44%)]	Loss: 0.022753
# Train: [150/225 (67%)]	Loss: 0.054579
# Train: [200/225 (89%)]	Loss: 0.066297
# Epoch: 51/100. Train set: Average loss: 0.0510
# Epoch: 51/100. Validation set: Average loss: 0.1922
# Estimated time of epoch: 55.7 s
# ETA:46.42 min
# Train: [0/225 (0%)]	Loss: 0.028132
# Train: [50/225 (22%)]	Loss: 0.045200
# Train: [100/225 (44%)]	Loss: 0.029183
# Train: [150/225 (67%)]	Loss: 0.051640
# Train: [200/225 (89%)]	Loss: 0.032381
# Epoch: 52/100. Train set: Average loss: 0.0389
# Epoch: 52/100. Validation set: Average loss: 0.1736
# Estimated time of epoch: 56.09 s
# ETA:45.81 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.072245
# Train: [100/225 (44%)]	Loss: 0.081876
# Train: [150/225 (67%)]	Loss: 0.084467
# Train: [200/225 (89%)]	Loss: 0.029131
# Epoch: 53/100. Train set: Average loss: 0.0595
# Epoch: 53/100. Validation set: Average loss: 0.1776
# Estimated time of epoch: 55.89 s
# ETA:44.71 min
# Train: [0/225 (0%)]	Loss: 0.081573
# Train: [50/225 (22%)]	Loss: 0.117926
# Train: [100/225 (44%)]	Loss: 0.048553
# Train: [150/225 (67%)]	Loss: 0.018372
# Train: [200/225 (89%)]	Loss: 0.077691
# Epoch: 54/100. Train set: Average loss: 0.0629
# Epoch: 54/100. Validation set: Average loss: 0.1794
# Estimated time of epoch: 56.03 s
# ETA:43.89 min
# Train: [0/225 (0%)]	Loss: 0.049447
# Train: [50/225 (22%)]	Loss: 0.029439
# Train: [100/225 (44%)]	Loss: 0.061797
# Train: [150/225 (67%)]	Loss: 0.068410
# Train: [200/225 (89%)]	Loss: 0.038580
# Epoch: 55/100. Train set: Average loss: 0.0553
# Epoch: 55/100. Validation set: Average loss: 0.1856
# Estimated time of epoch: 56.12 s
# ETA:43.03 min
# Train: [0/225 (0%)]	Loss: 0.222772
# Train: [50/225 (22%)]	Loss: 0.061900
# Train: [100/225 (44%)]	Loss: 0.031906
# Train: [150/225 (67%)]	Loss: 0.052012
# Train: [200/225 (89%)]	Loss: 0.016237
# Epoch: 56/100. Train set: Average loss: 0.0438
# Epoch: 56/100. Validation set: Average loss: 0.1661
# Estimated time of epoch: 55.63 s
# ETA:41.72 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.096478
# Train: [100/225 (44%)]	Loss: 0.058383
# Train: [150/225 (67%)]	Loss: 0.035278
# Train: [200/225 (89%)]	Loss: 0.043500
# Epoch: 57/100. Train set: Average loss: 0.0519
# Epoch: 57/100. Validation set: Average loss: 0.1669
# Estimated time of epoch: 56.05 s
# ETA:41.1 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.052914
# Train: [100/225 (44%)]	Loss: 0.032607
# Train: [150/225 (67%)]	Loss: 0.055442
# Train: [200/225 (89%)]	Loss: 0.056317
# Epoch: 58/100. Train set: Average loss: 0.0466
# Epoch: 58/100. Validation set: Average loss: 0.1717
# Estimated time of epoch: 56.28 s
# ETA:40.33 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.097902
# Train: [100/225 (44%)]	Loss: 0.105982
# Train: [150/225 (67%)]	Loss: 0.054645
# Train: [200/225 (89%)]	Loss: 0.118764
# Epoch: 59/100. Train set: Average loss: 0.0937
# Epoch: 59/100. Validation set: Average loss: 0.1725
# Estimated time of epoch: 56.66 s
# ETA:39.66 min
# Train: [0/225 (0%)]	Loss: 0.056656
# Train: [50/225 (22%)]	Loss: 0.047728
# Train: [100/225 (44%)]	Loss: 0.056400
# Train: [150/225 (67%)]	Loss: 0.061001
# Train: [200/225 (89%)]	Loss: 0.031823
# Epoch: 60/100. Train set: Average loss: 0.0475
# Epoch: 60/100. Validation set: Average loss: 0.1753
# Estimated time of epoch: 56.13 s
# ETA:38.36 min
# Train: [0/225 (0%)]	Loss: 0.253649
# Train: [50/225 (22%)]	Loss: 0.069559
# Train: [100/225 (44%)]	Loss: 0.052464
# Train: [150/225 (67%)]	Loss: 0.026212
# Train: [200/225 (89%)]	Loss: 0.054558
# Epoch: 61/100. Train set: Average loss: 0.0582
# Epoch: 61/100. Validation set: Average loss: 0.1827
# Estimated time of epoch: 56.39 s
# ETA:37.59 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.014515
# Train: [100/225 (44%)]	Loss: 0.092537
# Train: [150/225 (67%)]	Loss: 0.090486
# Train: [200/225 (89%)]	Loss: 0.027813
# Epoch: 62/100. Train set: Average loss: 0.0584
# Epoch: 62/100. Validation set: Average loss: 0.1821
# Estimated time of epoch: 56.23 s
# ETA:36.55 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.145598
# Train: [100/225 (44%)]	Loss: 0.066991
# Train: [150/225 (67%)]	Loss: 0.047915
# Train: [200/225 (89%)]	Loss: 0.068603
# Epoch: 63/100. Train set: Average loss: 0.0858
# Epoch: 63/100. Validation set: Average loss: 0.1882
# Estimated time of epoch: 55.79 s
# ETA:35.33 min
# Train: [0/225 (0%)]	Loss: 0.031032
# Train: [50/225 (22%)]	Loss: 0.085464
# Train: [100/225 (44%)]	Loss: 0.040348
# Train: [150/225 (67%)]	Loss: 0.018197
# Train: [200/225 (89%)]	Loss: 0.018663
# Epoch: 64/100. Train set: Average loss: 0.0407
# Epoch: 64/100. Validation set: Average loss: 0.1840
# Estimated time of epoch: 58.69 s
# ETA:36.19 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.062229
# Train: [100/225 (44%)]	Loss: 0.038934
# Train: [150/225 (67%)]	Loss: 0.075962
# Train: [200/225 (89%)]	Loss: 0.055383
# Epoch: 65/100. Train set: Average loss: 0.0530
# Epoch: 65/100. Validation set: Average loss: 0.1665
# Estimated time of epoch: 56.05 s
# ETA:33.63 min
# Train: [0/225 (0%)]	Loss: 0.027902
# Train: [50/225 (22%)]	Loss: 0.034510
# Train: [100/225 (44%)]	Loss: 0.051374
# Train: [150/225 (67%)]	Loss: 0.043640
# Train: [200/225 (89%)]	Loss: 0.024690
# Epoch: 66/100. Train set: Average loss: 0.0612
# Epoch: 66/100. Validation set: Average loss: 0.1632
# Estimated time of epoch: 56.41 s
# ETA:32.91 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.108289
# Train: [100/225 (44%)]	Loss: 0.073619
# Train: [150/225 (67%)]	Loss: 0.065858
# Train: [200/225 (89%)]	Loss: 0.016931
# Epoch: 67/100. Train set: Average loss: 0.0627
# Epoch: 67/100. Validation set: Average loss: 0.1598
# Estimated time of epoch: 56.15 s
# ETA:31.82 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.079741
# Train: [100/225 (44%)]	Loss: 0.022327
# Train: [150/225 (67%)]	Loss: 0.052103
# Train: [200/225 (89%)]	Loss: 0.055987
# Epoch: 68/100. Train set: Average loss: 0.0470
# Epoch: 68/100. Validation set: Average loss: 0.1731
# Estimated time of epoch: 56.07 s
# ETA:30.84 min
# Train: [0/225 (0%)]	Loss: 0.017862
# Train: [50/225 (22%)]	Loss: 0.004147
# Train: [100/225 (44%)]	Loss: 0.100854
# Train: [150/225 (67%)]	Loss: 0.069340
# Train: [200/225 (89%)]	Loss: 0.072475
# Epoch: 69/100. Train set: Average loss: 0.0580
# Epoch: 69/100. Validation set: Average loss: 0.1624
# Estimated time of epoch: 56.24 s
# ETA:29.99 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.050818
# Train: [100/225 (44%)]	Loss: 0.092358
# Train: [150/225 (67%)]	Loss: 0.022166
# Train: [200/225 (89%)]	Loss: 0.017584
# Epoch: 70/100. Train set: Average loss: 0.0422
# Epoch: 70/100. Validation set: Average loss: 0.1758
# Estimated time of epoch: 56.44 s
# ETA:29.16 min
# Train: [0/225 (0%)]	Loss: 0.034022
# Train: [50/225 (22%)]	Loss: 0.030806
# Train: [100/225 (44%)]	Loss: 0.078830
# Train: [150/225 (67%)]	Loss: 0.035190
# Train: [200/225 (89%)]	Loss: 0.042393
# Epoch: 71/100. Train set: Average loss: 0.0451
# Epoch: 71/100. Validation set: Average loss: 0.1684
# Estimated time of epoch: 56.61 s
# ETA:28.3 min
# Train: [0/225 (0%)]	Loss: 0.089381
# Train: [50/225 (22%)]	Loss: 0.039333
# Train: [100/225 (44%)]	Loss: 0.022694
# Train: [150/225 (67%)]	Loss: 0.020890
# Train: [200/225 (89%)]	Loss: 0.035030
# Epoch: 72/100. Train set: Average loss: 0.0330
# Epoch: 72/100. Validation set: Average loss: 0.1615
# Estimated time of epoch: 56.36 s
# ETA:27.24 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.038138
# Train: [100/225 (44%)]	Loss: 0.015978
# Train: [150/225 (67%)]	Loss: 0.010440
# Train: [200/225 (89%)]	Loss: 0.017054
# Epoch: 73/100. Train set: Average loss: 0.0201
# Epoch: 73/100. Validation set: Average loss: 0.1633
# Estimated time of epoch: 55.94 s
# ETA:26.11 min
# Train: [0/225 (0%)]	Loss: 0.165077
# Train: [50/225 (22%)]	Loss: 0.048206
# Train: [100/225 (44%)]	Loss: 0.067625
# Train: [150/225 (67%)]	Loss: 0.018947
# Train: [200/225 (89%)]	Loss: 0.023256
# Epoch: 74/100. Train set: Average loss: 0.0443
# Epoch: 74/100. Validation set: Average loss: 0.1599
# Estimated time of epoch: 56.38 s
# ETA:25.37 min
# Train: [0/225 (0%)]	Loss: 0.314211
# Train: [50/225 (22%)]	Loss: 0.026512
# Train: [100/225 (44%)]	Loss: 0.078739
# Train: [150/225 (67%)]	Loss: 0.020780
# Train: [200/225 (89%)]	Loss: 0.043351
# Epoch: 75/100. Train set: Average loss: 0.0662
# Epoch: 75/100. Validation set: Average loss: 0.1568
# Estimated time of epoch: 55.79 s
# ETA:24.18 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.014929
# Train: [100/225 (44%)]	Loss: 0.047392
# Train: [150/225 (67%)]	Loss: 0.061639
# Train: [200/225 (89%)]	Loss: 0.087510
# Epoch: 76/100. Train set: Average loss: 0.0570
# Epoch: 76/100. Validation set: Average loss: 0.1609
# Estimated time of epoch: 56.32 s
# ETA:23.47 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.072914
# Train: [100/225 (44%)]	Loss: 0.000000
# Train: [150/225 (67%)]	Loss: 0.012716
# Train: [200/225 (89%)]	Loss: 0.048415
# Epoch: 77/100. Train set: Average loss: 0.0336
# Epoch: 77/100. Validation set: Average loss: 0.1686
# Estimated time of epoch: 56.42 s
# ETA:22.57 min
# Train: [0/225 (0%)]	Loss: 0.002047
# Train: [50/225 (22%)]	Loss: 0.015014
# Train: [100/225 (44%)]	Loss: 0.051008
# Train: [150/225 (67%)]	Loss: 0.049644
# Train: [200/225 (89%)]	Loss: 0.017911
# Epoch: 78/100. Train set: Average loss: 0.0320
# Epoch: 78/100. Validation set: Average loss: 0.1600
# Estimated time of epoch: 56.17 s
# ETA:21.53 min
# Train: [0/225 (0%)]	Loss: 0.004424
# Train: [50/225 (22%)]	Loss: 0.021859
# Train: [100/225 (44%)]	Loss: 0.018052
# Train: [150/225 (67%)]	Loss: 0.067582
# Train: [200/225 (89%)]	Loss: 0.021074
# Epoch: 79/100. Train set: Average loss: 0.0297
# Epoch: 79/100. Validation set: Average loss: 0.1458
# Estimated time of epoch: 56.99 s
# ETA:20.9 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.017654
# Train: [100/225 (44%)]	Loss: 0.060544
# Train: [150/225 (67%)]	Loss: 0.080363
# Train: [200/225 (89%)]	Loss: 0.065450
# Epoch: 80/100. Train set: Average loss: 0.0498
# Epoch: 80/100. Validation set: Average loss: 0.1518
# Estimated time of epoch: 55.96 s
# ETA:19.59 min
# Train: [0/225 (0%)]	Loss: 0.110933
# Train: [50/225 (22%)]	Loss: 0.010040
# Train: [100/225 (44%)]	Loss: 0.030712
# Train: [150/225 (67%)]	Loss: 0.024322
# Train: [200/225 (89%)]	Loss: 0.023210
# Epoch: 81/100. Train set: Average loss: 0.0253
# Epoch: 81/100. Validation set: Average loss: 0.1555
# Estimated time of epoch: 56.04 s
# ETA:18.68 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.054062
# Train: [100/225 (44%)]	Loss: 0.068178
# Train: [150/225 (67%)]	Loss: 0.011502
# Train: [200/225 (89%)]	Loss: 0.078952
# Epoch: 82/100. Train set: Average loss: 0.0509
# Epoch: 82/100. Validation set: Average loss: 0.1508
# Estimated time of epoch: 56.52 s
# ETA:17.9 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.105597
# Train: [100/225 (44%)]	Loss: 0.040825
# Train: [150/225 (67%)]	Loss: 0.035710
# Train: [200/225 (89%)]	Loss: 0.027874
# Epoch: 83/100. Train set: Average loss: 0.0494
# Epoch: 83/100. Validation set: Average loss: 0.1442
# Estimated time of epoch: 56.33 s
# ETA:16.9 min
# Train: [0/225 (0%)]	Loss: 0.377406
# Train: [50/225 (22%)]	Loss: 0.087285
# Train: [100/225 (44%)]	Loss: 0.047097
# Train: [150/225 (67%)]	Loss: 0.055774
# Train: [200/225 (89%)]	Loss: 0.032988
# Epoch: 84/100. Train set: Average loss: 0.0580
# Epoch: 84/100. Validation set: Average loss: 0.1317
# Estimated time of epoch: 59.09 s
# ETA:16.74 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.064206
# Train: [100/225 (44%)]	Loss: 0.018464
# Train: [150/225 (67%)]	Loss: 0.019427
# Train: [200/225 (89%)]	Loss: 0.034620
# Epoch: 85/100. Train set: Average loss: 0.0308
# Epoch: 85/100. Validation set: Average loss: 0.1515
# Estimated time of epoch: 56.19 s
# ETA:14.98 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.074279
# Train: [100/225 (44%)]	Loss: 0.050169
# Train: [150/225 (67%)]	Loss: 0.042709
# Train: [200/225 (89%)]	Loss: 0.023977
# Epoch: 86/100. Train set: Average loss: 0.0443
# Epoch: 86/100. Validation set: Average loss: 0.1509
# Estimated time of epoch: 55.98 s
# ETA:13.99 min
# Train: [0/225 (0%)]	Loss: 0.034129
# Train: [50/225 (22%)]	Loss: 0.053519
# Train: [100/225 (44%)]	Loss: 0.022138
# Train: [150/225 (67%)]	Loss: 0.052147
# Train: [200/225 (89%)]	Loss: 0.019342
# Epoch: 87/100. Train set: Average loss: 0.0352
# Epoch: 87/100. Validation set: Average loss: 0.1360
# Estimated time of epoch: 56.14 s
# ETA:13.1 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.064361
# Train: [100/225 (44%)]	Loss: 0.028190
# Train: [150/225 (67%)]	Loss: 0.011602
# Train: [200/225 (89%)]	Loss: 0.005122
# Epoch: 88/100. Train set: Average loss: 0.0243
# Epoch: 88/100. Validation set: Average loss: 0.1455
# Estimated time of epoch: 55.95 s
# ETA:12.12 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.080665
# Train: [100/225 (44%)]	Loss: 0.025702
# Train: [150/225 (67%)]	Loss: 0.024515
# Train: [200/225 (89%)]	Loss: 0.037017
# Epoch: 89/100. Train set: Average loss: 0.0461
# Epoch: 89/100. Validation set: Average loss: 0.1485
# Estimated time of epoch: 55.84 s
# ETA:11.17 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.042280
# Train: [100/225 (44%)]	Loss: 0.012119
# Train: [150/225 (67%)]	Loss: 0.049757
# Train: [200/225 (89%)]	Loss: 0.025720
# Epoch: 90/100. Train set: Average loss: 0.0304
# Epoch: 90/100. Validation set: Average loss: 0.1485
# Estimated time of epoch: 56.17 s
# ETA:10.3 min
# Train: [0/225 (0%)]	Loss: 0.015717
# Train: [50/225 (22%)]	Loss: 0.021415
# Train: [100/225 (44%)]	Loss: 0.047493
# Train: [150/225 (67%)]	Loss: 0.029259
# Train: [200/225 (89%)]	Loss: 0.027999
# Epoch: 91/100. Train set: Average loss: 0.0353
# Epoch: 91/100. Validation set: Average loss: 0.1427
# Estimated time of epoch: 55.7 s
# ETA:9.28 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.041671
# Train: [100/225 (44%)]	Loss: 0.028308
# Train: [150/225 (67%)]	Loss: 0.033132
# Train: [200/225 (89%)]	Loss: 0.019133
# Epoch: 92/100. Train set: Average loss: 0.0340
# Epoch: 92/100. Validation set: Average loss: 0.1421
# Estimated time of epoch: 55.69 s
# ETA:8.35 min
# Train: [0/225 (0%)]	Loss: 0.028662
# Train: [50/225 (22%)]	Loss: 0.000000
# Train: [100/225 (44%)]	Loss: 0.036690
# Train: [150/225 (67%)]	Loss: 0.014113
# Train: [200/225 (89%)]	Loss: 0.086993
# Epoch: 93/100. Train set: Average loss: 0.0313
# Epoch: 93/100. Validation set: Average loss: 0.1447
# Estimated time of epoch: 56.68 s
# ETA:7.56 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.013393
# Train: [100/225 (44%)]	Loss: 0.042430
# Train: [150/225 (67%)]	Loss: 0.064444
# Train: [200/225 (89%)]	Loss: 0.009213
# Epoch: 94/100. Train set: Average loss: 0.0289
# Epoch: 94/100. Validation set: Average loss: 0.1512
# Estimated time of epoch: 56.4 s
# ETA:6.58 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.015919
# Train: [100/225 (44%)]	Loss: 0.036426
# Train: [150/225 (67%)]	Loss: 0.066599
# Train: [200/225 (89%)]	Loss: 0.072200
# Epoch: 95/100. Train set: Average loss: 0.0433
# Epoch: 95/100. Validation set: Average loss: 0.1476
# Estimated time of epoch: 56.46 s
# ETA:5.65 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.037186
# Train: [100/225 (44%)]	Loss: 0.056876
# Train: [150/225 (67%)]	Loss: 0.020087
# Train: [200/225 (89%)]	Loss: 0.005197
# Epoch: 96/100. Train set: Average loss: 0.0301
# Epoch: 96/100. Validation set: Average loss: 0.1342
# Estimated time of epoch: 57.45 s
# ETA:4.79 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.054386
# Train: [100/225 (44%)]	Loss: 0.021961
# Train: [150/225 (67%)]	Loss: 0.007856
# Train: [200/225 (89%)]	Loss: 0.019091
# Epoch: 97/100. Train set: Average loss: 0.0253
# Epoch: 97/100. Validation set: Average loss: 0.1348
# Estimated time of epoch: 56.5 s
# ETA:3.77 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.015375
# Train: [100/225 (44%)]	Loss: 0.050665
# Train: [150/225 (67%)]	Loss: 0.037734
# Train: [200/225 (89%)]	Loss: 0.045664
# Epoch: 98/100. Train set: Average loss: 0.0353
# Epoch: 98/100. Validation set: Average loss: 0.1561
# Estimated time of epoch: 58.71 s
# ETA:2.94 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.023211
# Train: [100/225 (44%)]	Loss: 0.040716
# Train: [150/225 (67%)]	Loss: 0.023738
# Train: [200/225 (89%)]	Loss: 0.086136
# Epoch: 99/100. Train set: Average loss: 0.0403
# Epoch: 99/100. Validation set: Average loss: 0.1656
# Estimated time of epoch: 59.03 s
# ETA:1.97 min
# Train: [0/225 (0%)]	Loss: 0.000000
# Train: [50/225 (22%)]	Loss: 0.020307
# Train: [100/225 (44%)]	Loss: 0.036463
# Train: [150/225 (67%)]	Loss: 0.014882
# Train: [200/225 (89%)]	Loss: 0.026988
# Epoch: 100/100. Train set: Average loss: 0.0232
# Epoch: 100/100. Validation set: Average loss: 0.1556
# Estimated time of epoch: 56.95 s
# ETA:0.95 min

# %%
import cv2
import numpy as np
from sklearn.manifold import TSNE
import matplotlib as mpl
import matplotlib.pyplot as plt
from tqdm import tqdm
from torchvision import transforms
from torch.autograd import Variable
import os
import pandas as pd
import seaborn as sns
# استخراج ویژگی‌ها با استفاده از مدل Siamese
#def generate_embeddings(data_loader, model):
#    with torch.no_grad():
#        #device = 'cuda'
#        model.eval()
#        #model.to(device)
#        labels = None
#        embeddings = None
#        for batch_idx, data in tqdm(enumerate(data_loader)):
#            batch_imgs, batch_labels = data
#            batch_labels = batch_labels.numpy()
#           # batch_imgs = Variable(batch_imgs.to('cuda'))
#            batch_E = model.get_embedding(batch_imgs)
#            batch_E = batch_E.data.cpu().numpy()
#            embeddings = np.concatenate((embeddings, batch_E), axis=0) if embeddings is not None else batch_E
#            labels = np.concatenate((labels, batch_labels), axis=0) if labels is not None else batch_labels
#    return embeddings, labels
def generate_embeddings(data_loader, model):
    with torch.no_grad():
        #device = 'cuda'
        model.eval()
        #model.to(device)
        embeddings = []
        labels = []
        for batch_imgs, batch_labels in data_loader:
            if device:
                batch_imgs = batch_imgs.cuda()
            batch_E = model.get_embedding(batch_imgs)
            embeddings.append(batch_E.cpu().numpy())
            labels.append(batch_labels.numpy())
    return np.concatenate(embeddings), np.concatenate(labels)

def vis_tSNE(embeddings, labels, backbone='Convnet'):
    num_samples = embeddings.shape[0]
    X_embedded = TSNE(n_components=2).fit_transform(embeddings[0:num_samples, :])
    plt.figure(figsize=(16, 16))
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd','#1fa7b4', '#fb7f0e', '#27a02c', '#da2758', '#a46abd','#af7bb4', '#fa7fbe', '#2baf2c', '#4f2d28', '#b4f7bd']
    labels_name = ['Pepper__bell___Bacterial_spot', 'Pepper__bell___healthy', 'Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight','Tomato__Target_Spot','Tomato__Tomato_mosaic_virus','Tomato__Tomato_YellowLeaf__Curl_Virus','Tomato_Bacterial_spot','Tomato_Early_blight','Tomato_healthy','Tomato_Late_blight','Tomato_Leaf_Mold','Tomato_Septoria_leaf_spot','Tomato_Spider_mites_Two_spotted_spider_mite']
    for i in range(16):
        inds = np.where(labels==i)[0]
        plt.scatter(X_embedded[inds,0], X_embedded[inds,1], alpha=.8, color=colors[i], s=200)
    # plt.title(f't-SNE', fontweight='bold', fontsize=24)
    plt.legend(labels_name, fontsize=30)
    plt.savefig(f'./tsne_{backbone}.png')

# ذخیره مدل
torch.save(siamese_model.state_dict(), "f:/Meysam-Khodarahi/PlantDiseaseDiagnosisFewShotLearning/siamese_triplet_net/siamese_model_EmbeddingGEnerator_State_improved.h5")
torch.save(siamese_model , "f:/Meysam-Khodarahi/PlantDiseaseDiagnosisFewShotLearning/siamese_triplet_net/siamese_model_EmbeddingGEnerator.h5")
    
    
# تعریف مدل سفارشی ViT
 
# class RefinedViT(nn.Module):
#     def __init__(self, original_vit_model, embedding_dim, num_classes):
#         super(RefinedViT, self).__init__()
#         # حذف لایه‌های ابتدایی
#         self.vit = nn.Sequential(*list(original_vit_model.children())[2:])  # لایه‌های ابتدایی حذف شده
#         #self.fc = nn.Linear(embedding_dim, num_classes)  # لایه نهایی برای طبقه بندی
#         #self.fc = nn.Linear(1280, num_classes)  # لایه نهایی برای طبقه بندی
#         self.fc = nn.Linear(1792, num_classes)
#         self.dropout = nn.Dropout(0.5)
#     def forward(self, x):
#         x = self.vit(x)
#         x = self.dropout(x)
#         x = self.fc(x)
#         return x    

class RefinedViT(nn.Module):
    def __init__(self, original_vit_model, num_classes):
        super(RefinedViT, self).__init__()
        # حفظ لایه‌های اصلی ViT
        self.num_patches = (224 // 16) * (224 // 16)  # برای تصویر 224x224 با پچ 16x16
        self.embed_dim = 768  # سایز استاندارد برای vit-base
        
        # تبدیل embedding به پچ‌ها
        self.embedding_to_patch = nn.Linear(1792, self.num_patches * self.embed_dim)
        
        # Position Embedding
        self.pos_embed = nn.Parameter(torch.zeros(1, self.num_patches + 1, self.embed_dim))
        
        # CLS Token
        self.cls_token = nn.Parameter(torch.zeros(1, 1, self.embed_dim))
        
        # Transformer Encoder
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=self.embed_dim,
            nhead=12,  # تعداد heads در self-attention
            dim_feedforward=3072,
            dropout=0.1,
            activation='gelu',
            batch_first=True
        )
        self.transformer_encoder = nn.TransformerEncoder(encoder_layer, num_layers=12)
        
        # لایه‌های نهایی
        self.norm = nn.LayerNorm(self.embed_dim)
        self.fc = nn.Linear(self.embed_dim, num_classes)
        self.dropout = nn.Dropout(0.1)

    def forward(self, x):
        batch_size = x.size(0)
        
        # تبدیل embedding به پچ‌ها
        x = self.embedding_to_patch(x)  # (batch_size, num_patches * embed_dim)
        x = x.view(batch_size, self.num_patches, self.embed_dim)  # (batch_size, num_patches, embed_dim)
        
        # اضافه کردن CLS token
        cls_tokens = self.cls_token.expand(batch_size, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)  # (batch_size, num_patches + 1, embed_dim)
        
        # اضافه کردن position embedding
        x = x + self.pos_embed
        
        # Transformer Encoder
        x = self.transformer_encoder(x)
        
        # استفاده از CLS token برای طبقه‌بندی
        x = x[:, 0]  # فقط CLS token
        x = self.norm(x)
        x = self.dropout(x)
        x = self.fc(x)
        
        return x    
    
# class RefinedViT(nn.Module):
#     def __init__(self, original_vit_model, embedding_dim, num_classes):
#         super(RefinedViT, self).__init__()
#         self.vit = nn.Sequential(*list(original_vit_model.children())[2:])
#         self.fc = nn.Linear(1792, num_classes)
#         self.dropout = nn.Dropout(0.5)
#         # تعریف Positional Embedding
#         self.positional_embedding = nn.Parameter(torch.zeros(1, num_patches + 1, embedding_dim))
    
#     def forward(self, x):
#         # اضافه کردن Positional Embedding
#         x = x + self.positional_embedding
#         x = self.vit(x)
#         x = self.dropout(x)
#         x = self.fc(x)
#         return x     

train_data = torchvision.datasets.ImageFolder(root=path_data + '/train/', transform=get_val_transforms())
train_loader = torch.utils.data.DataLoader(train_data, batch_size=32)

test_data = torchvision.datasets.ImageFolder(root=path_data + '/test/', transform=get_val_transforms())
test_loader = torch.utils.data.DataLoader(test_data, batch_size=32)

# بارگذاری مدل ViT از Hugging Face
vit_model = ViTForImageClassification.from_pretrained('google/vit-base-patch16-224')
vit_model.classifier = torch.nn.Linear(vit_model.config.hidden_size, 15)  # تعداد کلاس‌ها

embedding_dim = vit_model.config.hidden_size  # ابعاد embedding
model = RefinedViT(vit_model, embedding_dim, num_classes=15)

# استخراج ویژگی‌ها از داده‌های آموزش
train_embeddings, train_labels = generate_embeddings(train_loader, siamese_model )
# استخراج ویژگی‌ها از داده‌های تست
test_embeddings, test_labels = generate_embeddings(test_loader, siamese_model )
 
# تبدیل داده‌ها به تنسور
X_train, y_train = train_embeddings, train_labels
X_val, y_val = test_embeddings, test_labels

X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_val_tensor = torch.tensor(X_val, dtype=torch.float32)
y_val_tensor = torch.tensor(y_val, dtype=torch.long)

# انتقال مدل به دستگاه CUDA
device = 'cuda' if torch.cuda.is_available() else 'cpu'
if torch.cuda.is_available():
    model.cuda()

# تنظیمات loss function و optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4)  # استفاده از AdamW
###############################
# تنظیمات مدل
vit_model = ViTForImageClassification.from_pretrained('google/vit-base-patch16-224')
model = RefinedViT(vit_model, num_classes=15)

# انتقال به GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
model = model.to(device)

# تنظیمات آموزش
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-4, weight_decay=0.01)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=1000)

# آموزش
model.train()
for epoch in range(1000):
    optimizer.zero_grad()
    outputs = model(X_train_tensor.to(device))
    loss = criterion(outputs, y_train_tensor.to(device))
    loss.backward()
    optimizer.step()
    scheduler.step()
    
    if (epoch + 1) % 10 == 0:
        print(f'Epoch [{epoch+1}/1000], Loss: {loss.item():.4f}')
########################################
# # آموزش مدل
# model.train()
# for epoch in range(1000):  # تعداد epochs
#     optimizer.zero_grad()
#     outputs = model(X_train_tensor.to(device))
#     loss = criterion(outputs, y_train_tensor.to(device))
#     loss.backward()
#     optimizer.step()
#     lr_scheduler.step()  # اعمال تغییرات در نرخ یادگیری
#     print(f'Epoch [{epoch+1}/1000], Loss: {loss.item():.4f}')

# ارزیابی مدل
model.eval()
with torch.no_grad():
    val_outputs = model(X_val_tensor.to(device))
    _, predicted = torch.max(val_outputs.data, 1)

# محاسبه دقت و امتیاز F1
accuracy = accuracy_score(y_val_tensor.cpu(), predicted.cpu())
f1 = f1_score(y_val_tensor.cpu(), predicted.cpu(), average='weighted')
precision = precision_score(y_val_tensor.cpu(), predicted.cpu(), average='macro') 
recall = recall_score(y_val_tensor.cpu(), predicted.cpu(), average='macro')

# نمایش نتایج
print(f'Accuracy: {accuracy:.4f}, F1 Score: {f1:.4f}')
print(f'Precision Score: {precision}')
print(f'Recall Score: {recall}')

# ذخیره مدل
torch.save(model.state_dict(), "f:/Meysam-Khodarahi/PlantDiseaseDiagnosisFewShotLearning/siamese_triplet_net/RVIT_State_improved.h5")
torch.save(model , "f:/Meysam-Khodarahi/PlantDiseaseDiagnosisFewShotLearning/siamese_triplet_net/RVIT_improved.h5")

# تابع تولید Embedding‌ها
def generate_embeddings(data_loader, model):
    with torch.no_grad():
        model.eval()
        embeddings = []
        labels = []
        for batch_imgs, batch_labels in data_loader:
            if device:
                batch_imgs = batch_imgs.cuda()
            batch_E = model.get_embedding(batch_imgs)  # استخراج ویژگی‌ها
            embeddings.append(batch_E.cpu().numpy())
            labels.append(batch_labels.numpy())
    return np.concatenate(embeddings), np.concatenate(labels)

# تابع vis_tSNE برای نمایش ویژگی‌ها
def vis_tSNE(embeddings, labels, backbone='EfficientNet'):
    num_samples = embeddings.shape[0]
    X_embedded = TSNE(n_components=2).fit_transform(embeddings[0:num_samples, :])
    plt.figure(figsize=(16, 16))
    colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd','#1fa7b4', '#fb7f0e', '#27a02c', '#da2758', '#a46abd','#af7bb4', '#fa7fbe', '#2baf2c', '#4f2d28', '#b4f7bd']
    labels_name = ['Pepper__bell___Bacterial_spot', 'Pepper__bell___healthy', 'Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight','Tomato__Target_Spot','Tomato__Tomato_mosaic_virus','Tomato__Tomato_YellowLeaf__Curl_Virus','Tomato_Bacterial_spot','Tomato_Early_blight','Tomato_healthy','Tomato_Late_blight','Tomato_Leaf_Mold','Tomato_Septoria_leaf_spot','Tomato_Spider_mites_Two_spotted_spider_mite']
    for i in range(15):
        inds = np.where(labels==i)[0]
        plt.scatter(X_embedded[inds,0], X_embedded[inds,1], alpha=.8, color=colors[i], s=200)
    plt.legend(labels_name, fontsize=30)
    plt.savefig(f'./tsne_{backbone}.png')

# نمایش t-SNE برای داده‌های تست
test_data = torchvision.datasets.ImageFolder(root=path_data + '/test/', transform=get_val_transforms())
test_loader = torch.utils.data.DataLoader(test_data, batch_size=32
# Epoch [945/1000], Loss: 0.8473
# Epoch [946/1000], Loss: 0.8599
# Epoch [947/1000], Loss: 0.8503
# Epoch [948/1000], Loss: 0.8443
# Epoch [949/1000], Loss: 0.8481
# Epoch [950/1000], Loss: 0.8377
# Epoch [951/1000], Loss: 0.8364
# Epoch [952/1000], Loss: 0.8449
# Epoch [953/1000], Loss: 0.8419
# Epoch [954/1000], Loss: 0.8506
# Epoch [955/1000], Loss: 0.8408
# Epoch [956/1000], Loss: 0.8335
# Epoch [957/1000], Loss: 0.8435
# Epoch [958/1000], Loss: 0.8325
# Epoch [959/1000], Loss: 0.8349
# Epoch [960/1000], Loss: 0.8321
# Epoch [961/1000], Loss: 0.8274
# Epoch [962/1000], Loss: 0.8284
# Epoch [963/1000], Loss: 0.8317
# Epoch [964/1000], Loss: 0.8335
# Epoch [965/1000], Loss: 0.8197
# Epoch [966/1000], Loss: 0.8300
# Epoch [967/1000], Loss: 0.8250
# Epoch [968/1000], Loss: 0.8211
# Epoch [969/1000], Loss: 0.8132
# Epoch [970/1000], Loss: 0.8263
# Epoch [971/1000], Loss: 0.8204
# Epoch [972/1000], Loss: 0.8178
# Epoch [973/1000], Loss: 0.8252
# Epoch [974/1000], Loss: 0.8198
# Epoch [975/1000], Loss: 0.8206
# Epoch [976/1000], Loss: 0.8165
# Epoch [977/1000], Loss: 0.8116
# Epoch [978/1000], Loss: 0.8153
# Epoch [979/1000], Loss: 0.8096
# Epoch [980/1000], Loss: 0.8099
# Epoch [981/1000], Loss: 0.8087
# Epoch [982/1000], Loss: 0.8058
# Epoch [983/1000], Loss: 0.8059
# Epoch [984/1000], Loss: 0.8140
# Epoch [985/1000], Loss: 0.7994
# Epoch [986/1000], Loss: 0.8067
# Epoch [987/1000], Loss: 0.8052
# Epoch [988/1000], Loss: 0.8103
# Epoch [989/1000], Loss: 0.8027
# Epoch [990/1000], Loss: 0.8040
# Epoch [991/1000], Loss: 0.8016
# Epoch [992/1000], Loss: 0.7976
# Epoch [993/1000], Loss: 0.7979
# Epoch [994/1000], Loss: 0.7987
# Epoch [995/1000], Loss: 0.7964
# Epoch [996/1000], Loss: 0.8009
# Epoch [997/1000], Loss: 0.7958
# Epoch [998/1000], Loss: 0.7983
# Epoch [999/1000], Loss: 0.7909
# Epoch [1000/1000], Loss: 0.7862
# Accuracy: 0.8525, F1 Score: 0.8510
# Precision Score: 0.8331714345050798
# Recall Score: 0.8614159609882334
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-e96560ef6840> in <module>
#     170 test_loader = torch.utils.data.DataLoader(test_data, batch_size=32)
#     171 val_embeddings_cl, val_labels_cl = generate_embeddings(test_loader, siamese_model)
# --> 172 vis_tSNE(val_embeddings_cl, val_labels_cl)
#     173
#     174 # نتیجه نهایی
#
# <ipython-input-29-e96560ef6840> in vis_tSNE(embeddings, labels, backbone)
#     162     for i in range(16):
#     163         inds = np.where(labels==i)[0]
# --> 164         plt.scatter(X_embedded[inds,0], X_embedded[inds,1], alpha=.8, color=colors[i], s=200)
#     165     plt.legend(labels_name, fontsize=30)
#     166     plt.savefig(f'./tsne_{backbone}.png')
#
# IndexError: list index out of range
